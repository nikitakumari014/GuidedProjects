# %%
#World Bank Science and Technology Data Analysis
print("Nikita Kumari, 2017657, CST SPL-1, 19")
# Out:
# Nikita Kumari, 2017657, CST SPL-1, 19

# %%
#importing the dataset
import pandas as pd

# %%
dataset = pd.read_csv("dataset/science_tech_2018.csv")
dataset
# Out:
#            Country Name  High-technology exports (% of manufactured exports)  \
# 0           Afghanistan                                                NaN
# 1               Albania                                           0.049514
# 2               Algeria                                                NaN
# 3        American Samoa                                                NaN
# 4               Andorra                                          28.460560
# ..                  ...                                                ...
# 214  West Bank and Gaza                                           0.850016
# 215               World                                          20.781626
# 216         Yemen, Rep.                                                NaN
# 217              Zambia                                           1.998840
# 218            Zimbabwe                                           2.050870
#
# ...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape #219 rows and 10 columns
# Out:
# (219, 10)

# %%
dataset.size
# Out:
# 2190

# %%
dataset.columns
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %%
dataset_2009 = pd.read_csv("science_tech_2009.csv")
dataset_2009.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                           1.328024
# 2         Algeria                                           0.653887
# 3  American Samoa                                                NaN
# 4         Andorra                                          12.192161
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                             10128935.0                         3456.0
# 2                              4616076.0                         5345.0
# 3                                    NaN                            NaN
# 4                             10402350.0                          785.0
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# ...

# %%
dataset_2009.shape
# Out:
# (219, 10)

# %%
#cleaning the data
#1. Missing data
dataset.isna()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0           False                                               True
# 1           False                                              False
# 2           False                                               True
# 3           False                                               True
# 4           False                                              False
# ..            ...                                                ...
# 214         False                                              False
# 215         False                                              False
# 216         False                                               True
# 217         False                                              False
# 218         False                                              False
#
#      High-technology exports (current US$)  Trademark applications, total  \
# ...

# %%
dataset.isna().sum()
# Out:
# Country Name                                             0
# High-technology exports (% of manufactured exports)     87
# High-technology exports (current US$)                   88
# Trademark applications, total                           86
# Trademark applications, direct resident                 91
# Trademark applications, direct nonresident              90
# Patent applications, residents                         101
# Patent applications, nonresidents                      100
# Scientific and technical journal articles               20
# Research and development expenditure (% of GDP)        146
# dtype: int64

# %%
dataset_clean = dataset.dropna() #it will drop all the rows which have missing values
dataset_clean
# Out:
#                Country Name  \
# 8                   Armenia
# 11                  Austria
# 12               Azerbaijan
# 17                  Belarus
# 18                  Belgium
# 24   Bosnia and Herzegovina
# 28        Brunei Darussalam
# 29                 Bulgaria
# 35                   Canada
# 42                 Colombia
# 48                  Croatia
# 52           Czech Republic
# 53                  Denmark
# 58         Egypt, Arab Rep.
# 62                  Estonia
# 67                  Finland
# 68                   France
# 72                  Georgia
# 73                  Germany
# 87                  Hungary
# 88                  Iceland
# 89                    India
# 90                Indonesia
# 93                  Ireland
# 95                   Israel
# 96                    Italy
# 98                    Japan
# 100              Kazakhstan
# 104             Korea, Rep.
# 106                  Kuwait
# 109                  Latvia
# 115               Lithuania
# ...

# %%
dataset_clean.shape
# Out:
# (51, 10)

# %%
dataset_2009_clean = dataset_2009.dropna()
dataset_2009_clean.shape
# Out:
# (56, 10)

# %%
#Exploratory Data Analysis
#1. Descriptive Statistics

# %%
pd.set_option('display.float_format', lambda x: '%.3f' %x)
dataset_clean.describe()
# Out:
#        High-technology exports (% of manufactured exports)  \
# count                                             51.000
# mean                                              11.874
# std                                                7.902
# min                                                0.042
# 25%                                                5.337
# 50%                                               10.368
# 75%                                               17.103
# max                                               36.347
#
#        High-technology exports (current US$)  Trademark applications, total  \
# count                                 51.000                         51.000
# mean                         25697867097.059                      44515.294
# std                          48690230335.519                      85393.786
# min                               115051.000                       1974.000
# ...

# %%
dataset_clean.describe().style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f52a7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >High-technology exports (% of manufactured exports)</th>
#       <th class="col_heading level0 col1" >High-technology exports (current US$)</th>
#       <th class="col_heading level0 col2" >Trademark applications, total</th>
#       <th class="col_heading level0 col3" >Trademark applications, direct resident</th>
#       <th class="col_heading level0 col4" >Trademark applications, direct nonresident</th>
#       <th class="col_heading level0 col5" >Patent applications, residents</th>
#       <th class="col_heading level0 col6" >Patent applications, nonresidents</th>
#       <th class="col_heading level0 col7" >Scientific and technical journal articles</th>
#       <th class="col_heading level0 col8" >Research and development expenditure (% of GDP)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#this is just to tell to create the plot straight underneath,where i type the code in my notebook

# %%
sns.boxplot(x=dataset_clean['High-technology exports (% of manufactured exports)'])
# Out:
# <AxesSubplot:xlabel='High-technology exports (% of manufactured exports)'>

# %%
sns.boxplot(x=dataset_2009_clean['High-technology exports (% of manufactured exports)'])
# Out:
# <AxesSubplot:xlabel='High-technology exports (% of manufactured exports)'>

# %%
#outliers
columns = dataset_clean.columns
columns
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %%
for i in range(1,len(columns)):
    fig = plt.figure(figsize=(10,5))
    sns.boxplot(x=dataset_clean[columns[i]])

# %%
articles = dataset_clean['Scientific and technical journal articles'].max()
articles
# Out:
# 422807.71

# %%
dataset[ dataset['Scientific and technical journal articles']==articles]
# Out:
#       Country Name  High-technology exports (% of manufactured exports)  \
# 207  United States                                             18.896
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 207                       156365524736.000                     464786.000
#
#      Trademark applications, direct resident  \
# 207                               342150.000
#
#      Trademark applications, direct nonresident  \
# 207                                  122636.000
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 207                      285095.000                         312046.000
#
#      Scientific and technical journal articles  \
# 207                                 422807.710
#
#      Research and development expenditure (% of GDP)
# 207                                            2.838

# %%
#Exploring Relationship
#1. Co-relations
dataset_clean.corr(method='pearson').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_48be5_row0_col0, #T_48be5_row1_col1, #T_48be5_row2_col2, #T_48be5_row3_col3, #T_48be5_row4_col4, #T_48be5_row5_col5, #T_48be5_row6_col6, #T_48be5_row7_col7, #T_48be5_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_48be5_row0_col1 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_48be5_row0_col2 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_48be5_row0_col3, #T_48be5_row8_col1, #T_48be5_row8_col6 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_48be5_row0_col4, #T_48be5_row8_col7 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_48be5_row0_col5, #T_48be5_row0_col6, #T_48be5_row0_col7, #T_48be5_row4_col8, #T_48be5_row6_col0, #T_48be5_row6_col1, #T_48be5_row8_col2, #T_48be5_row8_col3, #T_48be5_row8_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_48be5_row0_col8 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_48be5_row1_col0 {
# ...

# %%
dataset_clean.corr(method='spearman').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_fb9a4_row0_col0, #T_fb9a4_row1_col1, #T_fb9a4_row2_col2, #T_fb9a4_row3_col3, #T_fb9a4_row4_col4, #T_fb9a4_row5_col5, #T_fb9a4_row6_col6, #T_fb9a4_row7_col7, #T_fb9a4_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_fb9a4_row0_col1, #T_fb9a4_row8_col1 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_fb9a4_row0_col2 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_fb9a4_row0_col3 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_fb9a4_row0_col4 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_fb9a4_row0_col5, #T_fb9a4_row0_col6, #T_fb9a4_row0_col7, #T_fb9a4_row4_col0, #T_fb9a4_row4_col1, #T_fb9a4_row4_col8, #T_fb9a4_row8_col2, #T_fb9a4_row8_col3, #T_fb9a4_row8_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_fb9a4_row0_col8, #T_fb9a4_row7_col6 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_fb9a4_row1_col0, #T_fb9a4_row2_col5 {
# ...

# %%
dataset_clean.plot.scatter(x='Scientific and technical journal articles',y='Patent applications, nonresidents')
# Out:
# <AxesSubplot:xlabel='Scientific and technical journal articles', ylabel='Patent applications, nonresidents'>

# %%
dataset_nonus = dataset_clean [ dataset_clean['Country Name'] != 'United States']

# %%
dataset_nonus.plot.scatter(x='Scientific and technical journal articles',y='Patent applications, nonresidents')
# Out:
# <AxesSubplot:xlabel='Scientific and technical journal articles', ylabel='Patent applications, nonresidents'>

# %%
#T-tests
import scipy.stats as stats

# %%
a = dataset_2009_clean['Patent applications, residents']
b = dataset_clean['Patent applications, residents']
stats.ttest_ind(a,b)
# Out:
# Ttest_indResult(statistic=0.17093628150351461, pvalue=0.8646028361752646)

# %%
for i in range(1,len(columns)):
    a = dataset_2009_clean[columns[i]]
    b = dataset_clean[columns[i]]
    print(stats.ttest_ind(a,b))
# Out:
# Ttest_indResult(statistic=1.5178124850425097, pvalue=0.13206686889029143)
# Ttest_indResult(statistic=0.12265583290103693, pvalue=0.902614099731734)
# Ttest_indResult(statistic=0.2704033385824462, pvalue=0.7873807591420726)
# Ttest_indResult(statistic=0.3877442167941513, pvalue=0.6989902537733603)
# Ttest_indResult(statistic=-0.48589263440463604, pvalue=0.628055750890876)
# Ttest_indResult(statistic=0.17093628150351461, pvalue=0.8646028361752646)
# Ttest_indResult(statistic=-0.044717907923683436, pvalue=0.9644170934929569)
# Ttest_indResult(statistic=-0.006105403997445266, pvalue=0.9951402075104707)
# Ttest_indResult(statistic=-0.27962305489587264, pvalue=0.7803167965750043)

# %%
print(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2312/4109613885.py in <module>
# ----> 1 print(false)
#
# NameError: name 'false' is not defined
